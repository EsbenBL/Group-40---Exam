# %%
import requests
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/Main_Page'
response = requests.get(url).text
soup = BeautifulSoup(response, 'html.parser')

links = soup.find_all('a')
links_clean = [link['href'] for link in links if link.has_attr('href')]
links_cleaner = [link for link in links_clean if '/wiki/' in link]
links_cleaner
# Out:
# ['/wiki/Wikipedia',
#  '/wiki/Free_content',
#  '/wiki/Encyclopedia',
#  '/wiki/Wikipedia:Introduction',
#  '/wiki/Special:Statistics',
#  '/wiki/English_language',
#  '/wiki/Portal:Arts',
#  '/wiki/Portal:Biography',
#  '/wiki/Portal:Geography',
#  '/wiki/Portal:History',
#  '/wiki/Portal:Mathematics',
#  '/wiki/Portal:Science',
#  '/wiki/Portal:Society',
#  '/wiki/Portal:Technology',
#  '/wiki/Portal:Contents/Portals',
#  '/wiki/File:Hillary_Clinton_official_Secretary_of_State_portrait_crop.jpg',
#  '/wiki/Hillary_Clinton',
#  '/wiki/First_Lady_of_the_United_States',
#  '/wiki/United_States_Senate',
#  '/wiki/New_York_(state)',
#  '/wiki/List_of_Secretaries_of_State_of_the_United_States',
#  '/wiki/United_States_Secretary_of_State',
#  '/wiki/Democratic_Party_(United_States)',
#  '/wiki/2016_United_States_presidential_election',
#  '/wiki/Park_Ridge,_Illinois',
#  '/wiki/Wellesley_College',
#  '/wiki/Yale_Law_School',
#  '/wiki/Bill_Clinton',
#  '/wiki/Legal_Services_Corporation',
#  '/wiki/Presidency_of_Barack_Obama',
#  '/wiki/Nuclear_program_of_Iran',
#  '/wiki/Joint_Comprehensive_Plan_of_Action',
#  '/wiki/Hillary_Clinton',
#  '/wiki/Marchioness_disaster',
#  '/wiki/Australia_women%27s_national_wheelchair_basketball_team_at_the_2012_Summer_Paralympics',
#  '/wiki/Trafford_Park',
#  '/wiki/Wikipedia:Today%27s_featured_article/August_2019',
#  '/wiki/Wikipedia:Featured_articles',
#  '/wiki/File:Kostantinos_Smolenski_(cropped).jpg',
#  '/wiki/Konstantinos_Smolenskis',
#  '/wiki/Greco-Turkish_War_(1897)',
#  '/wiki/Leonidas_Smolents',
#  '/wiki/2003_FIFA_Women%27s_World_Cup',
#  '/wiki/Severe_acute_respiratory_syndrome',
#  '/wiki/David_Cooper_(abolitionist)',
#  '/wiki/New_Jersey_General_Assembly',
#  '/wiki/Congress_of_the_Confederation',
#  '/wiki/George_Washington',
#  '/wiki/Cozzi_porcelain',
#  '/wiki/Jan_Gralewski',
#  '/wiki/1943_Gibraltar_B-24_crash',
#  '/wiki/Greater_Egyptian_gerbil',
#  '/wiki/Lesser_Egyptian_gerbil',
#  '/wiki/Bobby_Bostic',
#  '/wiki/Missouri',
#  '/wiki/Wayne_and_Shuster',
#  '/wiki/Stratford_Festival',
#  '/wiki/A_Shakespearean_Baseball_Game',
#  '/wiki/Wikipedia:Recent_additions',
#  '/wiki/Help:Your_first_article',
#  '/wiki/Template_talk:Did_you_know',
#  '/wiki/File:Ural_Airlines,_VQ-BOZ,_Airbus_A321-211_(16456198165).jpg',
#  '/wiki/17_August_2019_Kabul_bombing',
#  '/wiki/Kabul',
#  '/wiki/Ural_Airlines_Flight_178',
#  '/wiki/Bird_strike',
#  '/wiki/Airbus_A321',
#  '/wiki/Typhoon_Lekima_(2019)',
#  '/wiki/Ryukyu_Islands',
#  '/wiki/East_China',
#  '/wiki/Morogoro_tanker_explosion',
#  '/wiki/Morogoro',
#  '/wiki/Portal:Current_events',
#  '/wiki/2019_Hong_Kong_anti-extradition_bill_protests',
#  '/wiki/Deaths_in_2019',
#  '/wiki/Damodar_Ganesh_Bapat',
#  '/wiki/Felice_Gimondi',
#  '/wiki/V._B._Chandrasekhar',
#  '/wiki/Vidya_Sinha',
#  '/wiki/Frank_Tsao',
#  '/wiki/Polly_Farmer',
#  '/wiki/Wikipedia:In_the_news/Candidates',
#  '/wiki/August_21',
#  '/wiki/File:Lincoln_Douglas.jpg',
#  '/wiki/1689',
#  '/wiki/Jacobite_risings',
#  '/wiki/Jacobitism',
#  '/wiki/James_II_of_England',
#  '/wiki/Battle_of_Dunkeld',
#  '/wiki/Covenanters',
#  '/wiki/William_III_of_England',
#  '/wiki/Dunkeld_and_Birnam',
#  '/wiki/1858',
#  '/wiki/Lincoln%E2%80%93Douglas_debates',
#  '/wiki/Abraham_Lincoln',
#  '/wiki/Stephen_A._Douglas',
#  '/wiki/Illinois',
#  '/wiki/United_States_Senate',
#  '/wiki/Ottawa,_Illinois',
#  '/wiki/1944',
#  '/wiki/World_War_II',
#  '/wiki/Operation_Tractable',
#  '/wiki/Falaise,_Calvados',
#  '/wiki/Operation_Overlord',
#  '/wiki/1963',
#  '/wiki/Army_of_the_Republic_of_Vietnam_Special_Forces',
#  '/wiki/X%C3%A1_L%E1%BB%A3i_Pagoda_raids',
#  '/wiki/Buddhism_in_Vietnam',
#  '/wiki/1969',
#  '/wiki/Al-Aqsa_Mosque',
#  '/wiki/Jerusalem',
#  '/wiki/Organisation_of_Islamic_Cooperation',
#  '/wiki/Baldwin_II_of_Jerusalem',
#  '/wiki/Emily_Tinne',
#  '/wiki/Emma_Mashinini',
#  '/wiki/August_20',
#  '/wiki/August_21',
#  '/wiki/August_22',
#  '/wiki/Wikipedia:Selected_anniversaries/August',
#  '/wiki/List_of_historical_anniversaries',
#  '/wiki/File:Total_Solar_Eclipse_8-21-17.jpg',
#  '/wiki/Solar_eclipse_of_August_21,_2017',
#  '/wiki/Solar_eclipse',
#  '/wiki/Contiguous_United_States',
#  '/wiki/Nunavut',
#  '/wiki/Chukchi_Peninsula',
#  '/wiki/Solar_eclipse_of_June_8,_1918',
#  '/wiki/Solar_eclipse_of_February_26,_1979',
#  '/wiki/Crowheart,_Wyoming',
#  '/wiki/Bracketing',
#  '/wiki/Corona',
#  '/wiki/New_moon',
#  '/wiki/Earthlight_(astronomy)',
#  '/wiki/Solar_prominence',
#  '/wiki/Lunar_limb',
#  'https://commons.wikimedia.org/wiki/User:Msadler13',
#  '/wiki/Template:POTD/2019-08-20',
#  '/wiki/Template:POTD/2019-08-19',
#  '/wiki/Template:POTD/2019-08-18',
#  '/wiki/Wikipedia:Picture_of_the_day/Archive',
#  '/wiki/Wikipedia:Featured_pictures',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Wikipedia:Help_desk',
#  '/wiki/Wikipedia:Local_Embassy',
#  '/wiki/Wikipedia:Reference_desk',
#  '/wiki/Wikipedia:News',
#  '/wiki/Wikipedia:Village_pump',
#  '/wiki/Wikimedia_Foundation',
#  'https://commons.wikimedia.org/wiki/',
#  'https://www.mediawiki.org/wiki/',
#  'https://meta.wikimedia.org/wiki/',
#  'https://en.wikibooks.org/wiki/',
#  'https://www.wikidata.org/wiki/',
#  'https://en.wikinews.org/wiki/',
#  'https://en.wikiquote.org/wiki/',
#  'https://en.wikisource.org/wiki/',
#  'https://species.wikimedia.org/wiki/',
#  'https://en.wikiversity.org/wiki/',
#  'https://en.wikivoyage.org/wiki/',
#  'https://en.wiktionary.org/wiki/',
#  '/wiki/English_language',
#  '/wiki/Special:Statistics',
#  'https://de.wikipedia.org/wiki/',
#  'https://es.wikipedia.org/wiki/',
#  'https://fr.wikipedia.org/wiki/',
#  'https://it.wikipedia.org/wiki/',
#  'https://nl.wikipedia.org/wiki/',
#  'https://ja.wikipedia.org/wiki/',
#  'https://pl.wikipedia.org/wiki/',
#  'https://pt.wikipedia.org/wiki/',
#  'https://ru.wikipedia.org/wiki/',
#  'https://sv.wikipedia.org/wiki/',
#  'https://vi.wikipedia.org/wiki/',
#  'https://zh.wikipedia.org/wiki/',
#  'https://ar.wikipedia.org/wiki/',
#  'https://id.wikipedia.org/wiki/',
#  'https://ms.wikipedia.org/wiki/',
#  'https://bg.wikipedia.org/wiki/',
#  'https://ca.wikipedia.org/wiki/',
#  'https://cs.wikipedia.org/wiki/',
#  'https://da.wikipedia.org/wiki/',
#  'https://eo.wikipedia.org/wiki/',
#  'https://eu.wikipedia.org/wiki/',
#  'https://fa.wikipedia.org/wiki/',
#  'https://ko.wikipedia.org/wiki/',
#  'https://hu.wikipedia.org/wiki/',
#  'https://no.wikipedia.org/wiki/',
#  'https://ro.wikipedia.org/wiki/',
#  'https://sr.wikipedia.org/wiki/',
#  'https://sh.wikipedia.org/wiki/',
#  'https://fi.wikipedia.org/wiki/',
#  'https://tr.wikipedia.org/wiki/',
#  'https://uk.wikipedia.org/wiki/',
#  'https://bs.wikipedia.org/wiki/',
#  'https://et.wikipedia.org/wiki/',
#  'https://el.wikipedia.org/wiki/',
#  'https://simple.wikipedia.org/wiki/',
#  'https://gl.wikipedia.org/wiki/',
#  'https://he.wikipedia.org/wiki/',
#  'https://hr.wikipedia.org/wiki/',
#  'https://lv.wikipedia.org/wiki/',
#  'https://lt.wikipedia.org/wiki/',
#  'https://ml.wikipedia.org/wiki/',
#  'https://nn.wikipedia.org/wiki/',
#  'https://sk.wikipedia.org/wiki/',
#  'https://sl.wikipedia.org/wiki/',
#  'https://th.wikipedia.org/wiki/',
#  'https://meta.wikimedia.org/wiki/List_of_Wikipedias',
#  '/wiki/Special:MyTalk',
#  '/wiki/Special:MyContributions',
#  '/wiki/Main_Page',
#  '/wiki/Talk:Main_Page',
#  '/wiki/Main_Page',
#  '/wiki/Main_Page',
#  '/wiki/Main_Page',
#  '/wiki/Portal:Contents',
#  '/wiki/Portal:Featured_content',
#  '/wiki/Portal:Current_events',
#  '/wiki/Special:Random',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  '/wiki/Help:Contents',
#  '/wiki/Wikipedia:About',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Special:RecentChanges',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  '/wiki/Special:WhatLinksHere/Main_Page',
#  '/wiki/Special:RecentChangesLinked/Main_Page',
#  '/wiki/Wikipedia:File_Upload_Wizard',
#  '/wiki/Special:SpecialPages',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q5296',
#  'https://commons.wikimedia.org/wiki/Main_Page',
#  'https://www.mediawiki.org/wiki/MediaWiki',
#  'https://meta.wikimedia.org/wiki/Main_Page',
#  'https://species.wikimedia.org/wiki/Main_Page',
#  'https://en.wikibooks.org/wiki/Main_Page',
#  'https://www.wikidata.org/wiki/Wikidata:Main_Page',
#  'https://wikimania.wikimedia.org/wiki/Wikimania',
#  'https://en.wikinews.org/wiki/Main_Page',
#  'https://en.wikiquote.org/wiki/Main_Page',
#  'https://en.wikisource.org/wiki/Main_Page',
#  'https://en.wikiversity.org/wiki/Wikiversity:Main_Page',
#  'https://en.wikivoyage.org/wiki/Main_Page',
#  'https://en.wiktionary.org/wiki/Wiktionary:Main_Page',
#  'https://ar.wikipedia.org/wiki/',
#  'https://bg.wikipedia.org/wiki/',
#  'https://bs.wikipedia.org/wiki/',
#  'https://ca.wikipedia.org/wiki/',
#  'https://cs.wikipedia.org/wiki/',
#  'https://da.wikipedia.org/wiki/',
#  'https://de.wikipedia.org/wiki/',
#  'https://et.wikipedia.org/wiki/',
#  'https://el.wikipedia.org/wiki/',
#  'https://es.wikipedia.org/wiki/',
#  'https://eo.wikipedia.org/wiki/',
#  'https://eu.wikipedia.org/wiki/',
#  'https://fa.wikipedia.org/wiki/',
#  'https://fr.wikipedia.org/wiki/',
#  'https://gl.wikipedia.org/wiki/',
#  'https://ko.wikipedia.org/wiki/',
#  'https://hr.wikipedia.org/wiki/',
#  'https://id.wikipedia.org/wiki/',
#  'https://it.wikipedia.org/wiki/',
#  'https://he.wikipedia.org/wiki/',
#  'https://ka.wikipedia.org/wiki/',
#  'https://lv.wikipedia.org/wiki/',
#  'https://lt.wikipedia.org/wiki/',
#  'https://hu.wikipedia.org/wiki/',
#  'https://ms.wikipedia.org/wiki/',
#  'https://nl.wikipedia.org/wiki/',
#  'https://ja.wikipedia.org/wiki/',
#  'https://no.wikipedia.org/wiki/',
#  'https://nn.wikipedia.org/wiki/',
#  'https://pl.wikipedia.org/wiki/',
#  'https://pt.wikipedia.org/wiki/',
#  'https://ro.wikipedia.org/wiki/',
#  'https://ru.wikipedia.org/wiki/',
#  'https://simple.wikipedia.org/wiki/',
#  'https://sk.wikipedia.org/wiki/',
#  'https://sl.wikipedia.org/wiki/',
#  'https://sr.wikipedia.org/wiki/',
#  'https://sh.wikipedia.org/wiki/',
#  'https://fi.wikipedia.org/wiki/',
#  'https://sv.wikipedia.org/wiki/',
#  'https://th.wikipedia.org/wiki/',
#  'https://tr.wikipedia.org/wiki/',
#  'https://uk.wikipedia.org/wiki/',
#  'https://vi.wikipedia.org/wiki/',
#  'https://zh.wikipedia.org/wiki/',
#  '//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#  '//foundation.wikimedia.org/wiki/Terms_of_Use',
#  '//foundation.wikimedia.org/wiki/Privacy_policy',
#  'https://foundation.wikimedia.org/wiki/Privacy_policy',
#  '/wiki/Wikipedia:About',
#  '/wiki/Wikipedia:General_disclaimer',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute',
#  'https://foundation.wikimedia.org/wiki/Cookie_statement']

# %%
print('test')
# Out:
# test
