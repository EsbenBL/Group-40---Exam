# %%
import pandas as pd
ink_df = pd.read_excel('Indkomstdata.xlsx')
df = pd.read_csv('Boliga - Behandling 3, Ledig, Udd, Indbygger.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ink_df.head()
# Out:
#                    Kommune  Kommunal_gennemsnitsinkomst_2017
# 0  Landsdel Byen København                            330285
# 1                København                            319745
# 2            Frederiksberg                            384186
# 3                   Dragør                            410044
# 4                   Tårnby                            322928

# %%
pd.options.display.max_columns = 200

# %%
df.head()
# Out:
#    Unnamed: 0 agentDisplayName  agentRegId  area  basementSize  buildYear  \
# 0           0              NaN       24254     1             0       1767
# 1           1              NaN         207     1            88       1880
# 2           2              NaN         117     1             0       1755
# 3           3              NaN       17151     1             0       1880
# 4           4              NaN       17489     1             0       1873
#
#           city               createdDate  daysForSale  domainId energyClass  \
# 0  København K  2019-05-22T00:35:07.000Z           93       944           -
# 1  København K  2019-06-14T03:27:01.490Z           70         7           C
# 2  København K  2019-04-24T00:09:51.880Z          121       171           C
# 3  København K  2019-05-08T00:04:30.737Z          107        91           C
# 4  København K  2019-07-12T03:21:26.060Z           42         9           C
#
# ...

# %%
df.shape
# Out:
# (65559, 66)

# %%
df = df.merge(ink_df, how='left', left_on = df['Kommune'], right_on = ink_df['Kommune'], validate = 'm:1')

# %%
df.shape
# Out:
# (65559, 69)

# %%
df.head()
# Out:
#        key_0  Unnamed: 0 agentDisplayName  agentRegId  area  basementSize  \
# 0  København           0              NaN       24254     1             0
# 1  København           1              NaN         207     1            88
# 2  København           2              NaN         117     1             0
# 3  København           3              NaN       17151     1             0
# 4  København           4              NaN       17489     1             0
#
#    buildYear         city               createdDate  daysForSale  domainId  \
# 0       1767  København K  2019-05-22T00:35:07.000Z           93       944
# 1       1880  København K  2019-06-14T03:27:01.490Z           70         7
# 2       1755  København K  2019-04-24T00:09:51.880Z          121       171
# 3       1880  København K  2019-05-08T00:04:30.737Z          107        91
# 4       1873  København K  2019-07-12T03:21:26.060Z           42         9
#
# ...

# %%
df = df.drop(columns=['Kommune_y'])

# %%
df.shape
# Out:
# (65559, 68)

# %%
df.to_csv('Boliga_Behandling4_inkomst.csv')
