# %%
import pandas as pd

df_house = pd.read_csv('housing_data_with_street_address_split.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_kommune = pd.read_csv('Gade_Postnr_Kommune.csv')
df_kommune = df_kommune.drop(columns = ['Unnamed: 0'])

# %%
#Test

df_kom_test = df_kommune.head(10)
df_house_test = df

# %%
for i in df_kommune:
    try:
        df_kommune = df_kommune.astype({'Postnr': int})
    except: 
        None

# %%
df_kommune
# Out:
#                           Gade    Kommune  Postnr
# 0          Abel Cathrines Gade  København  1654.0
# 1                     Bygården  København  2700.0
# 2                 Aberdeengade  København  2150.0
# 3                    Dompapvej  København  2300.0
# 4              Abildgaardsgade  København  2100.0
# 5                  Skovharevej  København  2300.0
# 6                 Svalehalevej  København     NaN
# 7                     Abildhøj  København  2700.0
# 8                    Abildvang  København  2700.0
# 9                   Abrikosvej  København  2400.0
# 10                Absalonsgade  København  1658.0
# 11                    Adelgade  København  1304.0
# 12                 Admiralgade  København  1066.0
# 13                  Adriansvej  København  2300.0
# 14                      Agerbo  København  2300.0
# 15               Agerhønestien  København  2770.0
# 16                Agerlandsvej  København  2300.0
# 17              Aggersborggade  København  2100.0
# ...

# %%
import numpy as np

for i in df_kommune['Postnr']:
    try:
        i = i.astype(int)
    except: 
        None
        
type(df_kommune['Postnr'][0])
# Out:
# numpy.float64

# %%
df_kommune

# %%
df_joined = df_house.merge(df_kommune, how='left', left_on=['postal'],
                           right_on=['Postnr'], validate="m:1")
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-38-9917d5a99185> in <module>()
#       1 df_joined = df_house.merge(df_kommune, how='left', left_on=['postal'],
# ----> 2                            right_on=['Postnr'], validate="m:1")
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# ...

# %%
df_joined.shape
# Out:
# (243, 45)

# %%
df_joined[['street', 'Gade']]
# Out:
#              street            Gade
# 0       Matildesvej     Matildesvej
# 1       Matildesvej     Matildesvej
# 2        Møgelbjerg      Møgelbjerg
# 3       Toftevangen     Toftevangen
# 4       Toftevangen     Toftevangen
# 5       Toftevangen     Toftevangen
# 6       Toftevangen     Toftevangen
# 7       Toftevangen     Toftevangen
# 8       Toftevangen     Toftevangen
# 9       Toftevangen     Toftevangen
# 10      Toftevangen     Toftevangen
# 11      Toftevangen     Toftevangen
# 12      Toftevangen     Toftevangen
# 13      Toftevangen     Toftevangen
# 14      Toftevangen     Toftevangen
# 15     Vesterhvarre    Vesterhvarre
# 16    Ølholm Kærvej   Ølholm Kærvej
# 17          Havmose         Havmose
# 18       Pileurtvej      Pileurtvej
# 19       Pileurtvej      Pileurtvej
# 20       Pileurtvej      Pileurtvej
# 21       Pileurtvej      Pileurtvej
# 22       Pileurtvej      Pileurtvej
# 23       Pileurtvej      Pileurtvej
# 24         Tranevej        Tranevej
# ...

# %%
df_house.shape

# %%
df_joined
